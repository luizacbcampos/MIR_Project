# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
dfa = pd.read_csv('dataframe.csv')
dfb = pd.read_csv('main.csv')

# %%
dfa
# Out:
#        peak_rank  points  year                  artist_name  \
# 0             69   151.0  1984                   Al Jarreau
# 1              4  1475.0  1980                George Benson
# 2             71   169.0  1983               Herbie Hancock
# 3             36   645.0  1979                The Crusaders
# 4             11   733.0  1967          Cannonball Adderley
# ...          ...     ...   ...                          ...
# 20054         87    14.0  2019                       Future
# 20055         99     2.0  2019                       Future
# 20056         92     9.0  2019                        Ozuna
# 20057         93     8.0  2019               Jonas Brothers
# 20058          9    92.0  2019  Chris Brown Featuring Drake
#
#                 song_title  weeks_charted_all_time  gender        genre  \
# 0                After All                     9.0    male         Jazz
# 1        Give Me The Night                    23.0    male         Jazz
# ...

# %%
dfa[dfa['energy'].isna()]
# Out:
#       peak_rank  points  year                   artist_name  \
# 2798         63   244.0  1993                          Shai
# 4508          1  1252.0  1970               George Harrison
# 6357          3  1184.0  1969  Creedence Clearwater Revival
#
#                             song_title  weeks_charted_all_time gender genre  \
# 2798                             Yours                    11.0   male   Pop
# 4508     My Sweet Lord/Isn't It A Pity                    14.0   male  Rock
# 6357  Down On The Corner/Fortunate Son                    15.0   male  Rock
#
#       falsetto  register  spoken spotify_id spotify_song spotify_artist  \
# 2798       0.0       6.0     5.0        NaN          NaN            NaN
# 4508       0.0       6.0     0.0        NaN          NaN            NaN
# 6357       0.0       8.0     0.0        NaN          NaN            NaN
#
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# ...

# %%
dfa['instrumentalness'].max()
# Out:
# 0.981

# %%
dfa['instrumentalness'].min()
# Out:
# 0.0

# %%
dfb
# Out:
#        gender  falsetto              spotify_id  acousticness  danceability  \
# 0        male       0.0  5g5EdgkfKVUceOTJtm0Kel        0.5730         0.487
# 1        male       0.0  62GYoGszQfROZswLee6W3O        0.3140         0.850
# 2        male       0.0  2nWHzbBWBOePUvAImQv2So        0.0317         0.878
# 3      female       0.0  6Llr9PVC1cirKUwu7Fle83        0.6030         0.505
# 4        male       0.0  6NF8MZ2trxckVBr82pyyPt        0.7190         0.544
# ...       ...       ...                     ...           ...           ...
# 19965    male       0.0  4ANFPo7dzs2DdPuONXC9bp        0.0091         0.881
# 19966    male       0.0  2QEnZJ8FwpBoyLKcFcgceT        0.0365         0.801
# 19967    male       0.0  3xEozpt8pAptvpH69iJhOw        0.7860         0.434
# 19968    male       0.0  0DiDStADDVh3SvAsoJAFMk        0.1080         0.795
# 19969    male       0.0  6XHVuErjQ4XNm6nDPVCxVX        0.1230         0.696
#
# ...

# %%
df = pd.merge(dfa, dfb, how='outer', on='spotify_id')

# %%
df['instrumentalness_y'].max()
# Out:
# 0.981

# %%
df.shape
# Out:
# (20059, 125)

# %%
df.head()
# Out:
#    peak_rank  points  year          artist_name           song_title  \
# 0         69   151.0  1984           Al Jarreau            After All
# 1          4  1475.0  1980        George Benson    Give Me The Night
# 2         71   169.0  1983       Herbie Hancock               Rockit
# 3         36   645.0  1979        The Crusaders          Street Life
# 4         11   733.0  1967  Cannonball Adderley  Mercy, Mercy, Mercy
#
#    weeks_charted_all_time gender_x genre  falsetto_x  register  spoken  \
# 0                     9.0     male  Jazz         0.0       7.0     0.0
# 1                    23.0     male  Jazz         0.0       7.0     0.0
# 2                     9.0     male   Pop         0.0       6.0     8.0
# 3                    16.0   female  Jazz         0.0       7.0     0.0
# 4                    11.0     male  Jazz         0.0       0.0     0.0
#
#                spotify_id               spotify_song       spotify_artist  \
# ...

# %%
df['artist_name'].nunique()
# Out:
# 6861

# %%
peak_rank 	points 	year 	artist_name 	weeks_charted_all_time 	gender_x 	genre

# %%
df = pd.read_csv('merged_data.csv', sep=';').drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#        peak_rank  points  year                  artist_name  \
# 0             69   151.0  1984                   Al Jarreau
# 1              4  1475.0  1980                George Benson
# 2             71   169.0  1983               Herbie Hancock
# 3             36   645.0  1979                The Crusaders
# 4             11   733.0  1967          Cannonball Adderley
# ...          ...     ...   ...                          ...
# 19971         87    14.0  2019                       Future
# 19972         99     2.0  2019                       Future
# 19973         92     9.0  2019                        Ozuna
# 19974         93     8.0  2019               Jonas Brothers
# 19975          9    92.0  2019  Chris Brown Featuring Drake
#
#                 song_title  weeks_charted_all_time gender_x        genre  \
# 0                After All                     9.0     male         Jazz
# 1        Give Me The Night                    23.0     male         Jazz
# ...

# %%
dfx = dfa[['duration_ms', 'instrumentalness', 'points']].dropna()
dfx.to_csv('dr_inst_pt.csv', sep=';')

# %%
aux = dfa[['duration_ms', 'instrumentalness', 'points', 'year']].groupby('year').mean().reset_index()
aux['duration_ms'] = aux['duration_ms'] / 1000
aux['duration_ms'] = aux['duration_ms'].astype(int)
aux['points'] = aux['points'].astype(int)
aux['instrumentalness'] = aux['instrumentalness'].round(3)
aux.to_csv('dr_inst_pt_year.csv', sep=';', index=False)
aux
# Out:
#     year  duration_ms  instrumentalness  points
# 0   1958          145             0.022     542
# 1   1959          147             0.025     606
# 2   1960          153             0.024     561
# 3   1961          154             0.017     500
# 4   1962          156             0.030     532
# ..   ...          ...               ...     ...
# 57  2015          221             0.006     667
# 58  2016          222             0.006     655
# 59  2017          214             0.008     576
# 60  2018          207             0.008     449
# 61  2019          199             0.009     247
#
# [62 rows x 4 columns]
